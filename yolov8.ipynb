# %% [markdown]
# <a href="https://colab.research.google.com/github/ThousandAI/AI-DeepLearning/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
path = "/content/drive/MyDrive/Colab Notebooks/demo.jpg"
image = cv2.imread(path)
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()

# %%
model = YOLO("yolov8n.pt")
results = model(new_image)
cv2.imwrite("yolov8_demo_n.jpg", results[0].plot())
# Out:
# 0: 448x640 3 persons, 1 chair, 1 dining table, 2 laptops, 118.8ms
# Speed: 0.7ms preprocess, 118.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# True

# %%
model = YOLO("yolov8x.pt")
results = model(new_image)
cv2.imwrite("yolov8_demo_x.jpg", results[0].plot())
# Out:
# 0: 448x640 3 persons, 2 cups, 1 chair, 1 dining table, 2 laptops, 1 book, 90.0ms
# Speed: 0.5ms preprocess, 90.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# True

# %%
image = cv2.imread("yolov8_demo_n.jpg")
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()

# %%
image = cv2.imread("yolov8_demo_x.jpg")
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()
